# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('train.csv')

# %%
train.isnull().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
test = pd.read_csv('test.csv')

# %%
test.isnull().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# dtype: int64

# %%
train.head()
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# 4     15.2  395.60  12.43  22.9

# %%
x = ['ID','crim','zn','indus','chas','nox','age','dis','rad','tax','ptratio','black','lstat']

# %%
xx = train[x]

# %%
y = ['medv']

# %%
yy = train[y]

# %%
xtrain,xtest,ytrain,ytest = train_test_split(xx,yy,test_size=0.2,random_state=40)

# %%
clf = LinearRegression()

# %%
clf.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
clf.score(xtrain,ytrain)
# Out:
# 0.6821033125307054

# %%
a = ['ID','crim','zn','indus','chas','nox','age','dis','rad','tax','ptratio','black','lstat']

# %%
aa = test[a]

# %%
p =clf.predict(aa)

# %%
test.ID.head()
# Out:
# 0     3
# 1     6
# 2     8
# 3     9
# 4    10
# Name: ID, dtype: int64

# %%
test.ID.isnull().sum()
# Out:
# 0

# %%
qq = p.ravel()
qq
# Out:
# array([28.93886294, 25.90149058, 17.9620748 ,  8.77363084, 18.13944861,
#        17.15138978, 20.60815794, 15.85107054, 14.56174255, 16.31238416,
#        18.58387171, 19.44019911,  5.40775152, 14.96968446, 26.13567404,
#        24.34828198, 25.2453756 , 26.39132373,  6.63057975, 27.73800992,
#        23.12085771, 25.05387129, 21.55508238, 21.81628809, 19.9209094 ,
#        23.29437786, 27.15085425, 28.13262794, 30.40932313, 28.49001347,
#        31.24236847, 30.92328059, 29.31888434, 22.08149047, 19.39667205,
#        20.10713084, 21.10807387, 20.07780585, 20.71063311, 23.99524625,
#        14.66130567, 19.23933278, 19.95280314, 15.60938748, 10.43138777,
#        11.63655135,  9.38195665, 17.50631205, 21.74319379, 26.93654284,
#        21.7457511 , 33.50792265, 40.12875345, 27.00705777, 25.5457464 ,
#        25.20744135, 33.52928161, 39.24448167, 35.07130989, 33.00961179,
#        29.85471867, 35.08982759, 17.46844465, 19.33012071, 23.9525493 ,
# ...

# %%
sub = pd.DataFrame({'ID':test.ID,'medv':qq})

# %%
sub.to_csv('noob.csv',index=False)

# %%
sub.shape
# Out:
# (173, 2)

# %%
train.info
# Out:
# <bound method DataFrame.info of       ID      crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0      1   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1      2   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2      4   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 3      5   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 4      7   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 5     11   0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 6     12   0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# 7     13   0.09378  12.5   7.87     0  0.524  5.889   39.0  5.4509    5  311
# 8     14   0.62976   0.0   8.14     0  0.538  5.949   61.8  4.7075    4  307
# 9     15   0.63796   0.0   8.14     0  0.538  6.096   84.5  4.4619    4  307
# 10    16   0.62739   0.0   8.14     0  0.538  5.834   56.5  4.4986    4  307
# ...
